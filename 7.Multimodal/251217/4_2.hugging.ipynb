# %%
# %pip install diffusers --upgrade
# Out:
# Requirement already satisfied: diffusers in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (0.36.0)
# Requirement already satisfied: importlib_metadata in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from diffusers) (8.7.0)
# Requirement already satisfied: filelock in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from diffusers) (3.20.0)
# Requirement already satisfied: httpx<1.0.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from diffusers) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from diffusers) (0.36.0)
# Requirement already satisfied: numpy in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from diffusers) (2.2.5)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from diffusers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from diffusers) (2.32.5)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from diffusers) (0.6.2)
# Requirement already satisfied: Pillow in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from diffusers) (11.1.0)
# Requirement already satisfied: anyio in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx<1.0.0->diffusers) (4.11.0)
# Requirement already satisfied: certifi in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx<1.0.0->diffusers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx<1.0.0->diffusers) (1.0.9)
# Requirement already satisfied: idna in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx<1.0.0->diffusers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpcore==1.*->httpx<1.0.0->diffusers) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (2025.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.15.0)
# Requirement already satisfied: colorama in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.34.0->diffusers) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from anyio->httpx<1.0.0->diffusers) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from anyio->httpx<1.0.0->diffusers) (1.3.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from importlib_metadata->diffusers) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from requests->diffusers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from requests->diffusers) (2.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install invisible_watermark transformers accelerate safetensors
# Out:
# Collecting invisible_watermark
#   Downloading invisible_watermark-0.2.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: transformers in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (4.57.1)
# Requirement already satisfied: accelerate in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (1.11.0)
# Requirement already satisfied: safetensors in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (0.6.2)
# Requirement already satisfied: Pillow>=6.0.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from invisible_watermark) (11.1.0)
# Collecting PyWavelets>=1.1.1 (from invisible_watermark)
#   Downloading pywavelets-1.8.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from invisible_watermark) (2.2.5)
# Collecting opencv-python>=4.1.0.25 (from invisible_watermark)
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: torch in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from invisible_watermark) (2.9.1)
# Requirement already satisfied: filelock in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: psutil in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from accelerate) (7.1.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from torch->invisible_watermark) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from torch->invisible_watermark) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from torch->invisible_watermark) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from sympy>=1.13.3->torch->invisible_watermark) (1.3.0)
# Requirement already satisfied: colorama in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from jinja2->torch->invisible_watermark) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from requests->transformers) (2025.11.12)
# Downloading invisible_watermark-0.2.0-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------------- ------- 1.3/1.6 MB 16.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 14.6 MB/s  0:00:00
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# Downloading pywavelets-1.8.0-cp310-cp310-win_amd64.whl (4.2 MB)
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ---------------------------------------- 4.2/4.2 MB 25.3 MB/s  0:00:00
# Installing collected packages: PyWavelets, opencv-python, invisible_watermark
#
#    ---------------------------------------- 0/3 [PyWavelets]
#    ---------------------------------------- 0/3 [PyWavelets]
#    ---------------------------------------- 0/3 [PyWavelets]
#    ---------------------------------------- 0/3 [PyWavelets]
#    ---------------------------------------- 0/3 [PyWavelets]
#    ---------------------------------------- 0/3 [PyWavelets]
#    ---------------------------------------- 0/3 [PyWavelets]
#    ---------------------------------------- 0/3 [PyWavelets]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    -------------------------- ------------- 2/3 [invisible_watermark]
#    -------------------------- ------------- 2/3 [invisible_watermark]
#    ---------------------------------------- 3/3 [invisible_watermark]
#
# Successfully installed PyWavelets-1.8.0 invisible_watermark-0.2.0 opencv-python-4.12.0.88
# Note: you may need to restart the kernel to use updated packages.

# %%
from diffusers import DiffusionPipeline
import torch

pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, use_safetensors=True, variant="fp16")
pipe.to("cuda")

# if using torch < 2.0
# pipe.enable_xformers_memory_efficient_attention()

prompt = "An astronaut riding a green horse"

images = pipe(prompt=prompt).images[0]

# %%
images.save('diffusion01.png')
