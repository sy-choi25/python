# %%
# !pip install python-dotenv

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5-nano",
    input="25년 11월 21일 서울과 경기도의 날씨와 22일 23일 날씨를 기상정보를 검색해서 알려줘"
)

print(response.output_text)
# Out:
# 요청하신 2025-11-21(오늘)과 11-22, 11-23의 서울 및 경기도 날씨를 정확히 알려드리려면 최신 기상 정보를 웹에서 확인해야 합니다. 현재 제 답변 창에서 실시간 웹 검색을 바로 수행하는 기능은 제공되지 않아요.
#
# 다음 중 원하시는 방법으로 도와드리겠습니다.
# - 방법 A: 제가 웹에서 최신 예보를 확인해 서울·경기도의 2025-11-21, 22, 23 각 날짜에 대해 필요한 항목(날씨 상태, 최저/최고 기온, 강수확률, 강수 형태, 바람)을 요약해 드립니다. 출처도 함께 표기합니다.
# - 방법 B: 웹 검색 대신 일반적인 11월 말 서울·경기도의 기후 경향과 옷차림 팁을 제공해 드립니다.
# - 방법 C: 사용 중인 날씨 앱이나 포털(예: KMA 날씨누리, 네이버/웨더)에서 확인하는 방법을 구체적으로 안내해 드립니다.
#
# 원하시는 방법을 알려주시면 바로 진행하겠습니다. 또한 특정 도시(예: 서울, 수원, 고양 등 경기도의 주요 도시)로 더 세부적으로 원하시는지 알려주시면 그에 맞춰 정리해 드릴게요.
