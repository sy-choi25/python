# %%
# 벡터검색 bm25 키워드 검색을 rrf 알고리즘으로 결합
from typing import List
from langchain_core.documents import Document
from langchain_community.retrievers import BM25Retriever

class FusionRetriveal:
    '''Fusion Retriveal 기법을 구현한 클래스'''
    def __init__(self,documents:List[Document],retriever_k : int =5):
        '''
        Args:
            documents : 전체문서 리스트
            retriever_k : 각 검색 방식 당 반환할 문서 개수
        '''
        self.documents=documents
        self.retriever_k = retriever_k
        #BM25 Retriever 초기화
        self.bm25_retriever = BM25Retriever.from_documents(documents)
        self.bm25_retriever.k = retriever_k
        print('Fusion Retrieval 초기화 완료')
    def fusion_retrieval(self, question:str , vector_retriever) -> List[Document]:
        '''
        벡터 겸색과 bm25 검색 결과를 rrf 알고리즘으로 결합
        Args:
            question : 사용자 질문
            vector_retriever : 벡터검색 retriever 객체
        returns :
            문서리스트
        '''
        # 벡터 검색
        vector_docs = vector_retriever.invoke(question)
        #bm25 검색
        bm25_docs = self.bm25_retriever.invoke(question)
        print('fusion_retrieval...')
        print(f' 벡터검색 : {len(vector_docs)}개 문서')
        print(f' bm25검색 : {len(bm25_docs)}개 문서')
        # RRF (reciprocal rank fusion) 점수 게싼
        fusion_scores = {}
        # 벡터 검색 결과 점수화
        for rank, doc in enumerate(vector_docs):
            doc_key = doc.page_content[:50]
            1/(60+rank)
            fusion_scores[doc_key] = fusion_scores.get(doc_key,0) + score
        # bm25 검색 결과 점수화
        for rank, doc in enumerate(bm25_docs):
            doc_key = doc.page_content[:50]
            1/(60+rank)
            fusion_scores[doc_key] = fusion_scores.get(doc_key,0) + score
        # 점수로 정렬
        sorted_docs = sorted(
            fusion_scores.items(),key=lambda x : x[1], reverse = True
        )
        # 문서객체 반환
        result = []
        for doc_text, score in sorted_docs[:self.retriever_k]:
            if doc.page_content.startswith(doc_text):
                result.append(doc)
                break
        print(f' RRF 통합결과: {len(result)}개 문서')
        print(f' RRF 각 검색 방식의 순위 역수를 합산해서 최종 순서를 결정')
        return result
    
    def get_detail_fusion_info(self,question:str, vector_retriever) -> dict :
        '''
        상세한 Fusion Retrieval 정보 반환
        Args:
            question : 사용자 질문
            vector_retrieval : 벡터 검색 vector_retrieval 객체
        Returns :
            Fusion Retrieval 상세 정보 Dict
        '''
        vector_doc = vector_retriever.invoke(question)
        bm25_docs = self.bm25_retriever.invoke(question)
        return {
            'vector_search_count' : len(vector_doc),
            'bm25_search_count' : len(bm25_docs),
            'vector_docs' : vector_doc,
            'bm25_docs' : bm25_docs
        }

# %%
# %pip install langchain-community

# %%
if __name__ == '__main__':
    from langchain_community.document_loaders import TextLoader
    from langchain_text_splitters import RecursiveCharacterTextSplitter
    print('문서 준비')
    loader = TextLoader('document.txt',encoding= 'utf-8')
    Documents = loader.load()
    print('청크 생성')
    splitter = RecursiveCharacterTextSplitter(
        chunk_size = 500,
        chunk_overlap = 70
    )
chunks = splitter.split_documents(Documents)
print(f'{len(chunks)}개 청크 생성')
print('벡터 스토어 준비')
from langchain_openai import OpenAIEmbeddings
from langchain.chroma import Chroma
import os
embeddings = OpenAIEmbeddings(
    model = 'text-embedding-3-small',
    api_key = os.environ.get('OPENAI_API_KEY')
)
vectorstore = Chroma.from_documents(
    chunks,
    embeddings,
    persist_directory = './chroma_db'
)

print('벡터스토어 준비완료')
print('리트리버 생성')
retrieval = vectorstore.as_retriever(search_kwargs = {'k':3})

question = 'Langchain의 요소는 무엇인가요?'

print('Fusion Retrieval 사용')
fusion = FusionRetriveal(chunks,3)
fusion_docs = fusion.fusion_retrieval(question,retrieval)
print(f'fusion 검색 결과 : {len(fusion_docs)}개')
# Out:
# 문서 준비
# 청크 생성
# 1개 청크 생성
# 벡터 스토어 준비
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 16
#      14 print('벡터 스토어 준비')
#      15 from langchain_openai import OpenAIEmbeddings
# ---> 16 from langchain.chroma import Chroma
#      17 import os
#      18 embeddings = OpenAIEmbeddings(
#      19     model = 'text-embedding-3-small',
#      20     api_key = os.environ.get('OPENAI_API_KEY')
#      21 )
#
# ModuleNotFoundError: No module named 'langchain.chroma'

# %%
# %pip install langchain_chroma
# Out:
# Collecting langchain_chroma
#   Using cached langchain_chroma-1.0.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: chromadb<2.0.0,>=1.0.20 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain_chroma) (1.3.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain_chroma) (1.1.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain_chroma) (2.2.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.12.4)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.25.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_chroma) (0.4.48)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_chroma) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain_chroma) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_chroma) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_chroma) (0.25.0)
# Requirement already satisfied: anyio in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.11.0)
# Requirement already satisfied: certifi in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.0.9)
# Requirement already satisfied: idna in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.16.0)
# Requirement already satisfied: six>=1.5 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_chroma) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_chroma) (2.3.0)
# Requirement already satisfied: pyproject_hooks in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.3.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.29.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (6.33.1)
# Requirement already satisfied: sympy in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.59b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.36.0)
# Requirement already satisfied: filelock in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2025.10.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.2.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from anyio->httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from anyio->httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.3.0)
# Using cached langchain_chroma-1.0.0-py3-none-any.whl (12 kB)
# Installing collected packages: langchain_chroma
# Successfully installed langchain_chroma-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain_openai
# Out:
# Collecting langchain_openai
#   Using cached langchain_openai-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain_openai) (1.1.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain_openai) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.4.48)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_openai) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain_openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.25.0)
# Requirement already satisfied: anyio in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (4.11.0)
# Requirement already satisfied: certifi in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain_openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.1.0->langchain_openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.11.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_openai) (2.3.0)
# Requirement already satisfied: colorama in c:\users\samsung\miniconda3\envs\llm_env\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain_openai) (0.4.6)
# Using cached langchain_openai-1.1.0-py3-none-any.whl (84 kB)
# Installing collected packages: langchain_openai
# Successfully installed langchain_openai-1.1.0
# Note: you may need to restart the kernel to use updated packages.
