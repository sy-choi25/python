# %%
# %pip install -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# %pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\samsung\miniconda3\envs\open\lib\site-packages (from beautifulsoup4) (4.15.0)
# Using cached beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Using cached soupsieve-2.8-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
#
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    ---------------------------------------- 2/2 [beautifulsoup4]
#
# Successfully installed beautifulsoup4-4.14.2 soupsieve-2.8
# Note: you may need to restart the kernel to use updated packages.

# %%
# 문서로딩 청킹
# RAG: 외부지식을 활용해서 LLM 품질 높임
# 원본문서(pdf txt doc) --> 문서로딩 (loader) --> 청킹(Splitter)  --> 임베딩/저장(VectorDB)

# %%
from langchain_core.documents import Document
doc = Document(
    page_content = '우리회사는 근속 10년이상이면 포상제도가 있습니다.',
    metadata = {
        "source": '01001.pdf',
        'page' : 1, 
        'author': '작성자',
        'created_at': '2025-11-27'
    }
)

# 문서로더 - txt
from langchain_community.document_loaders import TextLoader, PyPDFLoader, WebBaseLoader,DirectoryLoader
loader = TextLoader('document.txt', encoding='utf-8')
documents = loader.load()
print (documents)
# Out:
# [Document(metadata={'source': 'document.txt'}, page_content='누리호 발사가 종료된 직후인 27일 새벽 2시40분 윤영빈 우주항공청장은 전남 고흥 나로우주센터에서 브리핑을 열고 “1시13분 누리호가 발사됐으며, 원격수신정보 초기 분석 결과 누리호가 차세대 중형위성 3호와 큐브위성 12기를 목표 궤도(600㎞)에 성공적으로 분리·안착시켰다”라고 밝혔다.\n\n이어 “1시55분 차세대 중형위성 3호와 남극세종기지 지상국 사이 첫 교신을 통해 태양전지판 전개 등 위성 상태가 정상임을 확인했다. 부탑재위성 12기도 일정에 따라 순차적으로 지상국과 교신해 상태를 확인할 예정”이라고 말했다. 누리호가 이날 궤도에 올린 위성 13기와의 교신 결과는 27일 낮 12시께 발표된다.')]

# %%
# 문서로더 - web
loader = WebBaseLoader("https://www.mk.co.kr/news/business/11477220")
documents_web = loader.load()
print (documents_web)
# Out:
# [Document(metadata={'source': 'https://www.mk.co.kr/news/business/11477220', 'title': '“제정신이냐”…격노한 젠슨 황, 엔비디아 직원들 질책한 이유는 - 매일경제', 'description': '“AI로 가능한 모든 작업 자동화”', 'language': 'ko'}, page_content="\n\n\n“제정신이냐”…격노한 젠슨 황, 엔비디아 직원들 질책한 이유는 - 매일경제\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n댓글정책\n\n\n\n공감순\n최신순\n오래된순\n\n\n\n\n\n\n\n\n\n뉴스 바로가기\n\n\n\n\n\n\n\n\n주가 정보\n\n\n\n\n\n\n\n\n\n\n\n\n매일 경제\n\n\n\n\n\n뉴스\nMK위클리연재\n스타투데이\n마켓\n부동산\n교육\n\n\n\n\n\n\n\n\nAI\n\n\n\n\n\n\n로그인\n\n\n\n\n회원가입\n\n\n\n\n로그아웃\n\n\n\n\n마이페이지\n\n\n\n\nENG\n\n\n\n\nJPN\n\n\n\n\nCHN\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n전체메뉴\n\n\n뉴스홈\n경제\n기업\n사회\n국제\n부동산\n증권\n정치\nIT·과학\n문화\n오피니언\n스포츠\n기획·연재\nSpecial Edition\n인기뉴스\n\n\n\n\n\n\n\n\n뉴스\n\n\n오피니언\n\n\n기획연재\n\n\n스페셜에디션\n\n\n스타투데이\n\n\n스포츠\n\n\n매경게임진\n\n\n\n\n\xa0\n\n\nPulse\n\n\nMK China\n\n\nMK빌리어드뉴스\n\n\n미라클아이\n\n\nMK ESG\n\n\n디그(dig)\n\n\n\n\n프리미엄\n\n\nMK위클리연재\n\n\n매경e신문\n\n\n레이더M\n\n\n오늘의 매경\n\n\n뉴스레터\n\n\nAI 오디오 뉴스\n\n\n매경엠플러스\n\n\nMK YouTube\n\n\n핵심 요약쏙\n\n\n\n\n재테크\n\n\n마켓\n\n\n부동산\n\n\n시사 경제 용어\n\n\n신설법인\n\n\n\n\n라이프\n\n\n골프\n\n\nBook\n\n\n여행\n\n\nM플레이\n\n\nCar\n\n\nAGL해외골프\n\n\nMK 장례\n\n\nMK 운세\n\n\n와글와글팝업\n\n\n매경출판\n\n\nMK AI GAMES\n\n\n\n\n비즈니스\n\n\nThe Biz Times\n\n\n닛케이텔레콤\n\n\n모바일 쿠폰\n\n\nMK Frame\n\n\n미라클랩\n\n\n\n\n캠페인\n\n\n세계지식포럼\n\n\n세계한상대회\n\n\n구독신청\n\n\n매경오픈\n\n\nMK멤버십\n\n\n사이트맵 바로가기\n\n\n\n\n전체메뉴 닫기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n검색어 지우기\n\n\n\n검색\n\n\n\n\n\n\n똑똑하게 질문하기\n\n\n\n\n한국 경제성장률 전망 알려줘\n\n\n\n\n\n최근 부동산 시장의 주요 트렌드는?\n\n\n\n\n\n최근 부동산 시장 동향과 정부의 경제 정책 변화 검색해줘\n\n\n\n\n\n최근 발표된 주요 기업들의 실적과 주가 분석 관련 기사 찾아줘\n\n\n\n\n\n\n\n\n\n\n\nAI 검색을 우선 설정합니다.\n\n\n\nPowered by\n\nperplexity\n\n\n\n\n\n\n\n\n통합검색 닫기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n전체메뉴\n\n\n\n\n매일 경제\n\n\n\n\n\n\n\n\n\n\n\n\n“제정신이냐”…격노한 젠슨 황, 엔비디아 직원들 질책한 이유는\n\n\n\n\n\n\n뉴스 요약쏙\n\n\n뉴스 요약쏙\nAI 요약은 OpenAI의 최신 기술을 활용해 핵심 내용을 빠르고 정확하게 제공합니다. 전체 맥락을 이해하려면 기사 본문을 함께 확인하는 것이 좋습니다.\n닫기\n\n젠슨 황 엔비디아 CEO는 최근 회의에서 일부 관리자들이 직원들에게 AI 사용을 줄이도록 지시한 것에 강하게 반발하며 AI의 자동화를 강조했다. 그는 AI를 통한 업무 자동화를 극대화하고 직원들의 고용 안정성에 대한 우려는 불필요하다고 언급하며, 엔비디아는 계속해서 채용을 진행할 것이라고 말했다. 현재 엔비디아 직원 수는 2025 회계연도 말까지 약 3만6000명으로 증가할 것으로 예상된다.\n\n\n\n\n회원용\n핵심 요약쏙은 회원용 콘텐츠입니다.\n매일경제 최신 뉴스를 요약해서 빠르게 읽을 수 있습니다.\n\n무료 회원 가입\n로그인\n\n\n\n\n\n\n\n\n\n언어 변경하기\n\n\n언어변경\n\n\n\nENG\n\n\n\n\nJPN\n\n\n\n\nCHN\n\n\n\n\n닫기\n\n\n\n\n\n\n글자 크기 변경하기\n\n\n글자크기 설정\n\n\n가\n\n\n가\n\n\n가\n\n\n가\n\n\n\n닫기\n\n\n\n\n\n\n인쇄하기\n\n\n\n\n\n공유하기\n\n\n기사 공유\n\n\n이메일에 공유하기\n\n\n카카오톡에 공유하기\n\n\n페이스북에 공유하기\n\n\n트위터에 공유하기\n\n\n링크 복사하기\n\n\n\n닫기\n\n\n\n\n\n\n스크랩 하기\n\n\n\n\n\n\n\n\n\n\n기사 상세\n\n\n\n\n\n\n\n\n\n\n\n\n기업\n\n\n“제정신이냐”…격노한 젠슨 황, 엔비디아 직원들 질책한 이유는\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTOP\n\n\n\n\n\n\n\n댓글 \n\n\n\n\n\n\n\n추천 기사\n\n\n\n\n\n\n\n\n\n한수진 기자\nhan.sujin@mk.co.kr\n\n\n\n\n입력\xa0:\xa0\n2025-11-26 10:07:43\n\n\n\n\n\n\n\n\n뉴스 요약쏙\n\n\n뉴스 요약쏙\nAI 요약은 OpenAI의 최신 기술을 활용해 핵심 내용을 빠르고 정확하게 제공합니다. 전체 맥락을 이해하려면 기사 본문을 함께 확인하는 것이 좋습니다.\n닫기\n\n젠슨 황 엔비디아 CEO는 최근 회의에서 일부 관리자들이 직원들에게 AI 사용을 줄이도록 지시한 것에 강하게 반발하며 AI의 자동화를 강조했다. 그는 AI를 통한 업무 자동화를 극대화하고 직원들의 고용 안정성에 대한 우려는 불필요하다고 언급하며, 엔비디아는 계속해서 채용을 진행할 것이라고 말했다. 현재 엔비디아 직원 수는 2025 회계연도 말까지 약 3만6000명으로 증가할 것으로 예상된다.\n\n\n\n\n회원용\n핵심 요약쏙은 회원용 콘텐츠입니다.\n매일경제 최신 뉴스를 요약해서 빠르게 읽을 수 있습니다.\n\n무료 회원 가입\n로그인\n\n\n\n\n\n\n\n\n\n언어 변경하기\n\n\n언어변경\n\n\n\nENG\n\n\n\n\nJPN\n\n\n\n\nCHN\n\n\n\n\n닫기\n\n\n\n\n\n\n글자 크기 변경하기\n\n\n글자크기 설정\n\n\n가\n\n\n가\n\n\n가\n\n\n가\n\n\n\n닫기\n\n\n\n\n\n\n인쇄하기\n\n\n\n\n\n공유하기\n\n\n기사 공유\n\n\n이메일에 공유하기\n\n\n카카오톡에 공유하기\n\n\n페이스북에 공유하기\n\n\n트위터에 공유하기\n\n\n링크 복사하기\n\n\n\n닫기\n\n\n\n\n\n\n스크랩 하기\n\n\n\n\n\n\n\n “AI로 가능한 모든 작업 자동화”        사진 확대    젠슨 황 엔비디아 최고경영자가 지난달 31일 2025년 아시아태평양경제협의체(APEC) 경주 엔비디아 기자간담회에 입장하는 모습. [연합뉴스]  젠슨 황 엔비디아 최고경영자(CEO)가 전체 회의에서 일부 직원들을 강하게 질책했다는 소식이 알려졌다.25일(현지 시간) 비즈니스 인사이더에 따르면 젠슨 황은 지난 20일 진행된 회의에서 “제가 알기로는 엔비디아의 일부 관리자들이 직원들에게 AI(인공지능) 사용을 줄이라고 지시하고 있다”며 “제정신이냐”고 말했다.그러면서 “AI로 자동화 가능한 모든 작업을 자동화하고 싶다”면서 “약속한다. ...

# %%
# 문서로더 - 디렉토리 로더
loader = DirectoryLoader (
    './',
    glob = "**/*.txt",
    loader_cls = TextLoader,  #loader_cls = TextLoader ==> 이거 안되면 경로 설정 loader_cls = lambda path: TextLoader(file_path=path, encoding = 'utf-8'), 로 작성하기
    show_progress=True
)
documents = loader.load()
print(documents)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 179.49it/s]
# [Document(metadata={'source': 'document.txt'}, page_content='누리호 발사가 종료된 직후인 27일 새벽 2시40분 윤영빈 우주항공청장은 전남 고흥 나로우주센터에서 브리핑을 열고 “1시13분 누리호가 발사됐으며, 원격수신정보 초기 분석 결과 누리호가 차세대 중형위성 3호와 큐브위성 12기를 목표 궤도(600㎞)에 성공적으로 분리·안착시켰다”라고 밝혔다.\n\n이어 “1시55분 차세대 중형위성 3호와 남극세종기지 지상국 사이 첫 교신을 통해 태양전지판 전개 등 위성 상태가 정상임을 확인했다. 부탑재위성 12기도 일정에 따라 순차적으로 지상국과 교신해 상태를 확인할 예정”이라고 말했다. 누리호가 이날 궤도에 올린 위성 13기와의 교신 결과는 27일 낮 12시께 발표된다.'), Document(metadata={'source': 'document1.txt'}, page_content='동해물과 백두산이 마르고 닳도록'), Document(metadata={'source': 'document2.txt'}, page_content='하느님이 보우사하 우리나라만세'), Document(metadata={'source': 'requirments.txt'}, page_content='python-dotenv>=1.0.0          # 환경변수 로드 (.env 파일)\nlangchain>=0.3.0              # LangChain 핵심 프레임워크\nlangchain-openai>=0.2.0       # OpenAI 연동\nlangchain-community>=0.3.0    # 커뮤니티 도구 (TextLoader, PyPDFLoader 등)\nlangchain-text-splitters>=0.3.0  # 텍스트 분할기\nlangchain-chroma>=0.1.0       # ChromaDB 연동\nlangchain-core>=0.3.0         # LangChain 핵심 모듈\nlanggraph>=0.2.0              # LangGraph 상태 기반 에이전트\npydantic>=2.0.0               # 데이터 검증\nnumpy>=1.24.0                 # 수치 연산\nchromadb>=0.5.0 ')]

# %%
# chunking : 긴 문서를 작은 조각(chunck)으로 분할
# LLM이 컨텍스트를 제한
# 검색의 정확도를 향상
# 검색의 정확도 향상(큰문서 관련없는 정보 포함) : 작은 청크 --> 질문과 관련된 부분문 검색

# 텍스트 분할기
from langchain_text_splitters import CharacterTextSplitter
spliiter = CharacterTextSplitter(
    separator= '\n',  #분할기준
    chunk_size = 1000, # 최대크기
    chunk_overlap=200
)

    # 우리는 오늘 식당에 가서 점심을 먹고 그리고 카페에 가서 커피를 시켰다. 그리고 10분에 영철이가 와서 ... 
    # ---> "우리는 오늘" // "오늘 식당에"  // "식당에 가서" ==> overlab

# 권장 : 여러구분자를 계층적으로 시도
from langchain_text_splitters import RecursiveCharacterTextSplitter
spliiter = RecursiveCharacterTextSplitter(
    separators= ['\n', '\n\n', '.'],  #분할기준
    chunk_size = 1000, # 최대크기
    chunk_overlap=200
)
