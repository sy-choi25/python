# %%
# DuckDuckGo 무료웹검색

# %%
# %pip install ddgs

# %%
# from duckduckgo_search import DDGS
from ddgs import DDGS
ddgs = DDGS()
# results = ddgs.text(
#     query = 'AI 인공지능',
#     region= 'ko-kr',
#     safesearch= 'moderate', # 안전검색
#     max_results = 10)


# for r in results :
#     print(f"{r['title']}\n")
#     print(f"{r['href']}\n")
#     print(f"{r['body']}\n")


# 뉴스
# results = ddgs.news(           
#     query = 'AI 인공지능',
#     region= 'ko-kr',
#     safesearch= 'moderate', # 안전검색
#     max_results = 10)


# for r in results :
#     print(f"{r}")

# 이미지
# results = ddgs.images(            
#     query = 'AI 인공지능',
#     # region= 'ko-kr',
#     region= 'wt_wt',
#     safesearch= 'moderate', # 안전검색
#     max_results = 10)

# for r in results :
#     print(f"{r}")


# 비디오
results = ddgs.videos(            
    query = 'LangGrahph tutorial',
    # region= 'ko-kr',
    region= 'wt_wt',
    safesearch= 'moderate', # 안전검색
    max_results = 10)


for r in results :
    print(f"{r}")

# 지역설정
print(''' 지역설정
ko-kr : 한국
ja-jp : 일본
en-us : 미국
en-gb : 영국
zh-cn : 중국
de-de : 독일
fr-fr : 프량스
wt-wt : 전세계                                               
''')


# RAG 하이브리드 
'''
사용자 질문 
내부문서 검색
문서평가 --> LLM으로 관련성 평가
if 충분함
    goto 답변생성
else
    duckduckgo 웹 검색    
    goto 답변생성

답변생성 --> LLM
'''

# Tavily VS duckduckgo
# Tavily : 검색 전체 데이터를 다 가져온다
# duckduckgo : 요약된 내용(하지만 출처도 있어서 필요하면 전체 내용을 크롤링)  빠르다. 어떠한 로그도 안 남는다(프라이버시 강함)
# Out:
# {'title': 'LangGraph Tutorial for Beginners: Build Your First AI Agent', 'content': 'https://www.youtube.com/watch?v=UklCxmEvz2w', 'description': "In this beginner-friendly tutorial, explore the fundamentals of LangGraph and learn how to build your first AI agent. Discover how to define AI agents as graphs and nodes, and integrate powerful tools like OpenAI for enhanced functionality. Whether you're new to AI development or looking to expand your skills, this comprehensive guide will walk ...", 'duration': '1:10:25', 'embed_html': '<iframe width="1280" height="720" src="https://www.youtube.com/embed/UklCxmEvz2w?autoplay=1" frameborder="0" allowfullscreen></iframe>', 'embed_url': 'https://www.youtube.com/embed/UklCxmEvz2w?autoplay=1', 'image_token': '3499037a141a018570a646b69359f03ee043bc5eb15bb7dfc3858aa0b20486c6', 'images': {'large': 'https://tse1.mm.bing.net/th/id/OVP.X-hD3-cSe5n7uLfu8GpaNAHgFo?pid=Api&ucfimg=1', 'medium': 'https://tse1.mm.bing.net/th/id/OVP.X-hD3-cSe5n7uLfu8GpaNAHgFo?pid=Api&ucfimg=1', 'motion': 'https://tse3.mm.bing.net/th/id/OM1.nL1944mHUguqbg_1752108451?pid=Api', 'small': 'https://tse1.mm.bing.net/th/id/OVP.X-hD3-cSe5n7uLfu8GpaNAHgFo?pid=Api&ucfimg=1'}, 'provider': 'Bing', 'published': '2025-06-27T16:45:02.0000000', 'publisher': 'YouTube', 'statistics': {'viewCount': 7592}, 'uploader': 'DataCamp'}
# {'title': 'Agentic AI Tutorial for Beginners | Langgraph Tutorial', 'content': 'https://www.youtube.com/watch?v=CnXdddeZ4tQ', 'description': 'Learn Agentic AI using a popular framework langgraph. In this agenti ai tutorial for beginners, we will start with agentic AI basics and then we will dive deeper into langgraph by covering a wide range of topics. 👉 Check out PyCharm, the IDE built for data science and AI/ML professionals: https://jb.gg/try-pycharm-now 👉 Download PyCharm ...', 'duration': '1:18:39', 'embed_html': '<iframe width="1280" height="720" src="https://www.youtube.com/embed/CnXdddeZ4tQ?autoplay=1" frameborder="0" allowfullscreen></iframe>', 'embed_url': 'https://www.youtube.com/embed/CnXdddeZ4tQ?autoplay=1', 'image_token': 'dca548cbd6ae2252e87ef98bf404de203b6f694dc9146bef4b20d28b5bdd0bdb', 'images': {'large': 'https://tse1.mm.bing.net/th/id/OVP.2vd1LU5B0Sm3-AtlQ2WcyAHgFo?pid=Api&ucfimg=1', 'medium': 'https://tse1.mm.bing.net/th/id/OVP.2vd1LU5B0Sm3-AtlQ2WcyAHgFo?pid=Api&ucfimg=1', 'motion': 'https://tse4.mm.bing.net/th/id/OM.MK5HqbLWB-lWFg_1764341309?pid=Api', 'small': 'https://tse1.mm.bing.net/th/id/OVP.2vd1LU5B0Sm3-AtlQ2WcyAHgFo?pid=Api&ucfimg=1'}, 'provider': 'Bing', 'published': '2025-06-27T13:30:07.0000000', 'publisher': 'YouTube', 'statistics': {'viewCount': 157722}, 'uploader': 'codebasics'}
# {'title': 'LangGraph Tutorial 2: Build Your First LangGraph | Practical Example with State, Nodes & Edges', 'content': 'https://www.youtube.com/watch?v=8h-shvIj1hk', 'description': "LangGraph Tutorial 2: Build Your First LangGraph - Practical Code Walkthrough In this follow-up to Tutorial 1, we move from theory to real code — building a working LangGraph step by step using Python. You'll learn exactly how to structure your state, define nodes, connect edges (including conditionals), and execute the graph to see ...", 'duration': '4:06', 'embed_html': '<iframe width="1280" height="720" src="https://www.youtube.com/embed/8h-shvIj1hk?autoplay=1" frameborder="0" allowfullscreen></iframe>', 'embed_url': 'https://www.youtube.com/embed/8h-shvIj1hk?autoplay=1', 'image_token': 'd86074bbc7223656010f4fda496557024e1c56815f377e016ad91fbb06a73efb', 'images': {'large': 'https://tse2.mm.bing.net/th/id/OVP.k5fa_Ly0vNV3EaLsxU0SlwEsDh?pid=Api&ucfimg=1', 'medium': 'https://tse2.mm.bing.net/th/id/OVP.k5fa_Ly0vNV3EaLsxU0SlwEsDh?pid=Api&ucfimg=1', 'motion': 'https://tse4.mm.bing.net/th/id/OM2.ZTkC17MRMESV2Q_1755623789?pid=Api', 'small': 'https://tse2.mm.bing.net/th/id/OVP.k5fa_Ly0vNV3EaLsxU0SlwEsDh?pid=Api&ucfimg=1'}, 'provider': 'Bing', 'published': '2025-07-16T18:23:07.0000000', 'publisher': 'YouTube', 'statistics': {'viewCount': 110}, 'uploader': 'A Venkatesh'}
# {'title': 'LangGraph Tutorial - How to Build Advanced AI Agent Systems', 'content': 'https://www.youtube.com/watch?v=1w5cCXlh7JQ', 'description': "Download PyCharm and use it for free forever with one month of Pro included: https://www.jetbrains.com/pycharm/ In this video, you're going to learn how to build AI agents using LangGraph. LangGraph is a much more professional and in-depth framework compared to something like LangChain or LlamaIndex, which allows you to build a really ...", 'duration': '46:49', 'embed_html': '<iframe width="1280" height="720" src="https://www.youtube.com/embed/1w5cCXlh7JQ?autoplay=1" frameborder="0" allowfullscreen></iframe>', 'embed_url': 'https://www.youtube.com/embed/1w5cCXlh7JQ?autoplay=1', 'image_token': '17dce4ad1784cbf078aa16a56d141b84615150209d8d9d127a29d3403da81af2', 'images': {'large': 'https://tse3.mm.bing.net/th/id/OVP.lzhWn_jfyf34tE0gNi1llAHgFo?pid=Api&ucfimg=1', 'medium': 'https://tse3.mm.bing.net/th/id/OVP.lzhWn_jfyf34tE0gNi1llAHgFo?pid=Api&ucfimg=1', 'motion': 'https://tse1.mm.bing.net/th/id/OM2.KxWFlzCtcjNnyg?pid=Api', 'small': 'https://tse3.mm.bing.net/th/id/OVP.lzhWn_jfyf34tE0gNi1llAHgFo?pid=Api&ucfimg=1'}, 'provider': 'Bing', 'published': '2025-05-05T12:54:24.0000000', 'publisher': 'YouTube', 'statistics': {'viewCount': 157613}, 'uploader': 'Tech With Tim'}
# {'title': 'Tutorial 1-Getting Started With LangGraph- Building Stateful Multi AI Agents', 'content': 'https://www.youtube.com/watch?v=gqvFmK7LpDo', 'description': 'LangGraph enables us to create stateful, multi-actor applications utilizing LLMs as easily as possible. It extends the capabilities of LangChain, introducing the ability to create and manage cyclical graphs, which are pivotal for developing sophisticated agent runtimes. The core concepts of LangGraph include: graph structure, state management ...', 'duration': '40:23', 'embed_html': '<iframe width="1280" height="720" src="https://www.youtube.com/embed/gqvFmK7LpDo?autoplay=1" frameborder="0" allowfullscreen></iframe>', 'embed_url': 'https://www.youtube.com/embed/gqvFmK7LpDo?autoplay=1', 'image_token': 'a0d7b5a5caee84645a5581852885acdbe62dce5cd4e94f9ca17685bdae102a98', 'images': {'large': 'https://tse1.mm.bing.net/th/id/OVP.ri3npb2ClTmakkN-VjeDiAHgFo?pid=Api&ucfimg=1', 'medium': 'https://tse1.mm.bing.net/th/id/OVP.ri3npb2ClTmakkN-VjeDiAHgFo?pid=Api&ucfimg=1', 'motion': 'https://tse3.mm.bing.net/th/id/OM.dKRcxS0McXKSSQ_1747035670?pid=Api', 'small': 'https://tse1.mm.bing.net/th/id/OVP.ri3npb2ClTmakkN-VjeDiAHgFo?pid=Api&ucfimg=1'}, 'provider': 'Bing', 'published': '2024-08-20T05:18:25.0000000', 'publisher': 'YouTube', 'statistics': {'viewCount': 132601}, 'uploader': 'Krish Naik'}
# {'title': 'LangGraph Full Course | Complete Beginner to Advanced Tutorial on Building AI Workflows & Agents', 'content': 'https://www.youtube.com/watch?v=Nqosv4dlzQM', 'description': 'Welcome to the Complete LangGraph Series (All 10 Videos Combined) — your full step-by-step guide to mastering LangGraph, the revolutionary framework for building AI-powered workflows and autonomous agents. Over the span of 10 episodes, we move from the absolute basics to advanced, real-world implementations — connecting AI models, tools ...', 'duration': '2:16:12', 'embed_html': '<iframe width="1280" height="720" src="https://www.youtube.com/embed/Nqosv4dlzQM?autoplay=1" frameborder="0" allowfullscreen></iframe>', 'embed_url': 'https://www.youtube.com/embed/Nqosv4dlzQM?autoplay=1', 'image_token': '3af475407a9b8c9c3be61c0f216a96e79a92085a56c2abf69435efd613d3cee2', 'images': {'large': 'https://tse3.mm.bing.net/th/id/OVP.r07OBOeGdQh2kL0KOYsFSQHgFo?pid=Api&ucfimg=1', 'medium': 'https://tse3.mm.bing.net/th/id/OVP.r07OBOeGdQh2kL0KOYsFSQHgFo?pid=Api&ucfimg=1', 'motion': '', 'small': 'https://tse3.mm.bing.net/th/id/OVP.r07OBOeGdQh2kL0KOYsFSQHgFo?pid=Api&ucfimg=1'}, 'provider': 'Bing', 'published': '2025-10-27T11:19:58.0000000', 'publisher': 'YouTube', 'statistics': {'viewCount': 771}, 'uploader': 'LearningHub'}
# {'title': 'LangGraph Tutorial | LangGraph Tutorials For Beginners | LangGraph agents | Simplilearn', 'content': 'https://www.youtube.com/watch?v=b6lpdm2xhFM', 'description': '🔥Purdue - Applied Generative AI Specialization - https://www.simplilearn.com/applied-ai-course?utm_campaign=b6lpdm2xhFM&utm_medium=DescriptionFirstFold&utm_source=Youtube 🔥Professional Certificate Program in Generative AI and Machine Learning - IITG (India Only) - https://www.simplilearn.com/iitg-generative-ai-machine-learning-program?utm ...', 'duration': '17:27', 'embed_html': '<iframe width="1280" height="720" src="https://www.youtube.com/embed/b6lpdm2xhFM?autoplay=1" frameborder="0" allowfullscreen></iframe>', 'embed_url': 'https://www.youtube.com/embed/b6lpdm2xhFM?autoplay=1', 'image_token': '91eb9275f6d29032347ba886c161ae77ff3b5fab40c23107ab4b948ad42366e8', 'images': {'large': 'https://tse2.mm.bing.net/th/id/OVP.oEGDP0DwvXr_S5nW3Oo8dwHgFo?pid=Api&ucfimg=1', 'medium': 'https://tse2.mm.bing.net/th/id/OVP.oEGDP0DwvXr_S5nW3Oo8dwHgFo?pid=Api&ucfimg=1', 'motion': 'https://tse4.mm.bing.net/th/id/OM.8ksiFZhPcRCLuw?pid=Api', 'small': 'https://tse2.mm.bing.net/th/id/OVP.oEGDP0DwvXr_S5nW3Oo8dwHgFo?pid=Api&ucfimg=1'}, 'provider': 'Bing', 'published': '2025-09-13T15:45:09.0000000', 'publisher': 'YouTube', 'statistics': {'viewCount': 1398}, 'uploader': 'Simplilearn'}
# {'title': 'Tutorials 2-Live Getting Started With LangGraph For Building AI Agents', 'content': 'https://www.youtube.com/watch?v=UltwJqpNA04', 'description': 'Register for the session : https://learn.krishnaikacademy.com/l/91b8976f97 LangGraph, created by LangChain, is an open source AI agent framework designed to build, deploy and manage complex generative AI agent workflows. It provides a set of tools and libraries that enable users to create, run and optimize large language models (LLMs) in a ...', 'duration': '1:08:59', 'embed_html': '<iframe width="1280" height="720" src="https://www.youtube.com/embed/UltwJqpNA04?autoplay=1" frameborder="0" allowfullscreen></iframe>', 'embed_url': 'https://www.youtube.com/embed/UltwJqpNA04?autoplay=1', 'image_token': 'efb6b67027ca936b2bf2b09f9c4ae6528926ba877ac8d76a1c3fcd07f71898d3', 'images': {'large': 'https://tse4.mm.bing.net/th/id/OVP.3IrkMzXR-rWAenL5UU2qWAEsDh?pid=Api&ucfimg=1', 'medium': 'https://tse4.mm.bing.net/th/id/OVP.3IrkMzXR-rWAenL5UU2qWAEsDh?pid=Api&ucfimg=1', 'motion': 'https://tse1.mm.bing.net/th/id/OM.clZ9c0JXnXP0Pg_1745946285?pid=Api', 'small': 'https://tse4.mm.bing.net/th/id/OVP.3IrkMzXR-rWAenL5UU2qWAEsDh?pid=Api&ucfimg=1'}, 'provider': 'Bing', 'published': '2025-04-11T16:20:09.0000000', 'publisher': 'YouTube', 'statistics': {'viewCount': 35776}, 'uploader': 'Krish Naik'}
# {'title': 'LangGraph Tutorial Complete Guide to Building AI Workflows', 'content': 'https://www.youtube.com/watch?v=wHQqjI9xSwo', 'description': 'In this lab you learn: Installing LangGraph locally Step 1: Defining the state and node functions Step 2: Initializing the graph and adding nodes Step 3: Defining the execution order with edges Step 4: Compile and run the workflow Video: https://github.com/starttraining/code/commit/1aa3e9647a36e47d53fb6edc1742a284e1930bb2', 'duration': '9:14', 'embed_html': '<iframe width="1280" height="720" src="https://www.youtube.com/embed/wHQqjI9xSwo?autoplay=1" frameborder="0" allowfullscreen></iframe>', 'embed_url': 'https://www.youtube.com/embed/wHQqjI9xSwo?autoplay=1', 'image_token': '860200ae4bda1bce171c864240f71e5d4dbbdb70a354ea07d6d143e5f43ec785', 'images': {'large': 'https://tse1.mm.bing.net/th/id/OVP.g5N05vqw2VNnttRNo4nVfQHgFo?pid=Api&ucfimg=1', 'medium': 'https://tse1.mm.bing.net/th/id/OVP.g5N05vqw2VNnttRNo4nVfQHgFo?pid=Api&ucfimg=1', 'motion': '', 'small': 'https://tse1.mm.bing.net/th/id/OVP.g5N05vqw2VNnttRNo4nVfQHgFo?pid=Api&ucfimg=1'}, 'provider': 'Bing', 'published': '2025-09-14T11:33:54.0000000', 'publisher': 'YouTube', 'statistics': {'viewCount': 6}, 'uploader': 'Start training'}
# {'title': 'Agentic AI using LangGraph | New Playlist | LangGraph Tutorial', 'content': 'https://www.youtube.com/watch?v=yC36gN-rqjo', 'description': "This playlist is your hands-on guide to building agentic AI systems using LangGraph—a powerful framework for managing multi-step, multi-agent workflows. You'll learn how to: Understand the core ideas behind agentic workflows Use LangGraph to define stateful agents and tasks Coordinate multiple tools, APIs, and LLM calls Handle memory ...", 'duration': '16:58', 'embed_html': '<iframe width="1280" height="720" src="https://www.youtube.com/embed/yC36gN-rqjo?autoplay=1" frameborder="0" allowfullscreen></iframe>', 'embed_url': 'https://www.youtube.com/embed/yC36gN-rqjo?autoplay=1', 'image_token': 'ed0cce1fc907e9c1fbbd51462d6786534f45efbb528e71a535f15e64bab9d732', 'images': {'large': 'https://tse1.mm.bing.net/th/id/OVP.01lHrcAdV9hzR8a2exiujgHgFo?pid=Api&ucfimg=1', 'medium': 'https://tse1.mm.bing.net/th/id/OVP.01lHrcAdV9hzR8a2exiujgHgFo?pid=Api&ucfimg=1', 'motion': 'https://tse4.mm.bing.net/th/id/OM.g7biF2xTKxou6Q_1752611703?pid=Api', 'small': 'https://tse1.mm.bing.net/th/id/OVP.01lHrcAdV9hzR8a2exiujgHgFo?pid=Api&ucfimg=1'}, 'provider': 'Bing', 'published': '2025-06-17T09:20:33.0000000', 'publisher': 'YouTube', 'statistics': {'viewCount': 139902}, 'uploader': 'CampusX'}
