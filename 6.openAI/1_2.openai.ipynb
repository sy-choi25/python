# %%
# 고객센터 - 
import os
import json
from openai import OpenAI
client = OpenAI()

# 가상의 고객 데이터
customer_reviews = [
    {'id' : 1,
     'product' : '무선 청소기',
     'date' : '2025-01-10',
     'content' : '너무 시끄럽고 충전이 잘 안되요 그냥 환불 하고 싶습니다. 박스는 버렸어요'
     },
    {'id' : 2,
     'product' : '여름용 셔츠',
     'date' : '2025-02-10',
     'content' : '사이즈가 광고랑 달라요 배송도 느리고 교환 가능한가요? 구매한지는 한달이 조금 넘었습니다.'
     },
    {'id' : 3,
     'product' : '블루투스 키보드',
     'date' : '2025-03-10',
     'content' : '블루투스가 잘 안잡혀요. 아니 인식이 안되는거 같아요.. 교환 또는 환불해주세요. 박스는 있어요'
     },
]
# 분류 - 판단 - 대응
# 회사의 환불/보상 규정( Knowledge Base for RAG)
policy_doc = '''
[다판다 교환/환불 및 보상 규정]
1. 단순 변심 환불 : 구매후 7일 이내 가능, 단 제품 박스가 온전해야 함
2. 제품 불량 환불 : 구매후 30일 이내 가능, 박스유무 상관 없음
3. 불만족 보상 : 구매 확정후에는 환불 불가, 소정의 적립금(2,000원) 지급 가능
4. AS 규정 : 구매 후 1년 이내 무상 AS 가능
'''

def ask_gpt_json(prompt):
    response = client.chat.completions.create(model = 'gpt-5-nano',
                                   messages=[{'role':'user','content':prompt}],
                                   response_format={'type':'json_object'}
                                   )
    try:
        return response.choices[0].message.content
    except:
        return None

# %%
# 단순히 요약이 아닌 카테고리, 감정점수, 핵심요구사항을 뽑아야함
def analyze_review(text):
    prompt = f'''
    너는 쇼핑몰 리뷰 전문가야, 아래 리뷰를 분석해서 다음 json 형식으로 출력
    
    [출력형식]
    {{
        'sentiment' : '긍정/부정/중립 중 하나',
        'category' : '배송/품질/서비스/기타 중 하나',
        'request_type' : '환불/교환/보상/AS/단순후기 중 하나',
        'key_issue' : "핵심 불만 사항(10자 이내)"
    }}

    [리뷰]
    {text}
    '''
    return json.loads(ask_gpt_json(prompt))  # 문자열 형태의 dict를 실제 객체로 변환

analzed_data_list = []
for item in customer_reviews:
    analysis = analyze_review( item['content'] )
    # 원본데이터에 분석 결과 합치기
    merged_data = {**item, **analysis}
    analzed_data_list.append(merged_data)

analzed_data_list
# Out:
# [{'id': 1,
#   'product': '무선 청소기',
#   'date': '2025-01-10',
#   'content': '너무 시끄럽고 충전이 잘 안되요 그냥 환불 하고 싶습니다. 박스는 버렸어요',
#   'sentiment': '부정',
#   'category': '품질',
#   'request_type': '환불',
#   'key_issue': '소음과충전불량'},
#  {'id': 2,
#   'product': '여름용 셔츠',
#   'date': '2025-02-10',
#   'content': '사이즈가 광고랑 달라요 배송도 느리고 교환 가능한가요? 구매한지는 한달이 조금 넘었습니다.',
#   'sentiment': '부정',
#   'category': '품질',
#   'request_type': '교환',
#   'key_issue': '사이즈 불일치'},
#  {'id': 3,
#   'product': '블루투스 키보드',
#   'date': '2025-03-10',
#   'content': '블루투스가 잘 안잡혀요. 아니 인식이 안되는거 같아요.. 교환 또는 환불해주세요. 박스는 있어요',
#   'sentiment': '부정',
#   'category': '품질',
#   'request_type': '교환',
#   'key_issue': '블루투스 인식 불가'}]

# %%
# ai가 멋대로 판단하지 않고 근거를 기반으로 생각하게 함
def make_decision(customer_data, policy_doc):
    prompt = f'''
        너는 베테랑 CS 매니저야
        아래 [고객 데이터]와 [회사규정]을 비교해서 요구사항을 들어줄 수 있는지 판단해

        [회사규정]
        {policy_doc}

        [고객데이터]
        - 구매일 : {customer_data['date']}
        - 오늘날짜 : 2025-11-24(기준)
        - 요청유형 : {customer_data['request_type']}
        - 내용 : {customer_data['content']}

        [지시사항]
        1. 규정의 몇 번 조항에 해당되는지 먼저 생각할 것(Cot)
        2. 날자를 계산해서 기간 내인지 확인할 것
        3. 최종 결정을 json으로 출력할 것

        [출력형식]
        {{
            'reasoning':'판단 근거(단계별 서술)',
            'decision':'승인/거절',
            'action_guide' : '상담원이 해야 할 행동 가이드'
        }}
    '''
    return json.loads(ask_gpt_json(prompt))

decision_results = []
for data in analzed_data_list:
    decision = make_decision(data,policy_doc)
    # 결과 저장
    final_result = {**data, 'decision_info':decision}
    decision_results.append(final_result)

    print(f'{data['id']} 판단결과')
    print(f'사유 : {decision['reasoning']}')
    print(f'결정 : {decision['decision']}')
    print(f'행동 가이드 : {decision['action_guide']}')
    print('-'*100)
# Out:
# 1 판단결과
# 사유 : 1) 적용 조항 판단: - 단순 변심 환불(조항 1)은 박스가 온전해야 한다는 조건이 있어 현재 박스가 없으므로 적합하지 않음. - 제품 불량 환불(조항 2)은 박스 유무와 무관하나 30일 이내에 가능하므로 이미 기간 초과로 불가. - 불만족 보상(조항 3)은 환불이 불가하더라도 소정의 적립금 지급 가능 여부를 검토하나 이 경우도 구체적 지급 조건이 운영 가이드에 따름. - AS 규정(조항 4)은 구매 후 1년 이내 무상 AS 가능으로 현재 상황에서 가장 타당한 해결 경로임. 따라서 환불 요구는 규정상 거절하되, AS를 통해 문제를 해결하는 방향이 적절함.
# 결정 : 거절/환불 불가, 대신 AS 가능(무상) 안내
# 행동 가이드 : 상담원이 따라야 할 절차: 1) 고객의 불편 사항에 공감 표명: 소음과 충전 문제에 대해 이해한다고 전하기. 2) 규정 요약 및 근거 설명: 현재 환불은 기간 초과로 불가, 단 AS는 1년 이내 무상 적용 가능함을 명확히 안내. 3) 가능 경로 제시: 1년 이내 무상 AS 접수 진행 안내. 필요한 정보 수집: 주문번호, 제품 모델, 시리얼 번호, 구매자 정보, 문제 발생 상황(소음 정도, 충전 문제 재현 여부). 4) AS 절차 안내: 접수 방법(온라인/전화), 서비스 센터 위치, 수리 예상 기간, 배송/수리 방식(수리비 여부 포함). 5) 박스 유무는 AS에는 영향이 없으므로 박스 유무와 관계 없이 AS 진행 가능하다고 안내. 6) 고객 선택에 따른 후속 조치: AS 접수 진행 후 상태 업데이트 제공. 7) 만약 고객이 특별 예외를 요청할 경우에는 상위 정책 여부 확인 및 필요 시 supervisor 승인을 요청하는 절차 안내. 8) 추가 대안 검토: 불만족 보상으로 소정의 적립금 지급 가능 여부를 확인해 필요 시 안내(정책상 가능 여부를 내부 가이드에 따름).
# ----------------------------------------------------------------------------------------------------
# 2 판단결과
# 사유 : Step 1) 규정을 확인: 다판다의 교환/환불 규정에는 명시적 ‘교환’ 조항이 없고, 해당 구분은 1) 단순 변심 환불(구매 후 7일 이내, 박스 온전 must) 2) 제품 불량 환불(구매 후 30일 이내, 박스 유무 무관) 3) 불만족 보상(구매 확정 후에는 환불 불가, 적립금 2,000원 지급 가능) 4) AS 규정(구매 후 1년 이내 무상)로 구성됩니다. 따라서 현재 요청은 ‘교환’에 대한 명시된 규정이 없어 보입니다. Step 2) 날짜 계산: 구매일 2025-02-10에서 오늘 date 2025-11-24까지의 경과일은 약 287일로, 7일 이내도 아니고 30일 이내도 아닙니다. 즉 단순 변심 환불이나 제품 불량 환불 요건도 충족되지 않습니다. AS는 1년 이내로 가능하나, 질환(사이즈 차이)로 인한 교환은 규정상 다루지 않습니다. Step 3) 판단: 규정상 교환 승인은 불가로 보는 것이 타당합니다. 다만 불만족 보상(2,000원 적립) 등 대안이 있을 수 있으며, 실제로는 AS나 불량 여부에 따른 판단 여부를 추가로 검토할 여지가 있습니다. But since 교환 자체는 명시된 규정에 해당하지 않으며 기간도 경과했으므로 교환 승인은 어렵습니다.
# 결정 : 거절
# 행동 가이드 : 상담원이 수행할 구체 가이드:
# - 고객에게 현재 규정상 교환은 명시되어 있지 않으며, 구매일로부터 287일이 경과해 단순 변심/제품 불량/AS의 기간도 현재 상황에 적용되기 어렵다고 정중히 안내합니다.
# - 대안 제시: 아래 중 하나 또는 복수로 제안합니다.
#   1) 불만족 보상 가능 여부 확인: 구매 확정 후 환불은 불가하지만 2,000원 적립금으로 보상 가능 여부를 확인하고 필요 시 적립금 지급 절차를 안내합니다.
#   2) AS 가능성 확인: 현재 시점에서 A/S는 1년 이내 가능하므로, 사이즈 문제로 인한 기능상 결함이나 불량 의심이 있다면 A/S 접수 절차를 안내합니다. 필요 시 사진/증빙을 요청합니다.
#   3) 교환 대신 할인/적립 등 대체 혜택 제안: 고객이 원한다면 향후 구매 시 사용할 수 있는 할인 쿠폰이나 포인트 적립 등으로 대체 혜택을 안내합니다.
# - 필요 서류 및 정보 수집: 주문번호, 상품명/모델, 광고 이미지와 비교 가능한 제품 사진, 사이즈 표/실제 치수 차이 사진, 배송 상황(배송 지연 여부)이 있다면 정리 요청합니다.
# - 커뮤니케이션 메시지 예시: “현재 정책상 교환은 명시되어 있지 않으며, 구매일로부터 287일이 경과하여 단순 변심/제품 불량 교환은 어렵습니다. 대신 불만족 보상(2,000원 적립), 또는 AS 가능 여부를 확인하여 도와드리겠습니다. 어떤 옵션으로 진행할까요?”
# - 내부 기록: 이 고객의 요청과 기간 경과, 제시 가능한 대안을 CRM에 남겨 추후 재검토나 예외 필요 시 상위 승인 요청 가능하도록 기록합니다.
# - 타임라인 안내: 적립금 지급 여부는 즉시 가능 여부를 확인하고, AS의 경우 접수 및 처리 기간을 고객에게 명확히 안내합니다.
# ----------------------------------------------------------------------------------------------------
# 3 판단결과
# 사유 : Cot: 4번 AS 규정 적용. 2) 기간 계산: 구매일 2025-03-10, 오늘 2025-11-24로 약 8개월 반 경과, 1년 이내 상태. 3) 판단: 고객의 교환/환불 요청은 규정상 7일 이내나 30일 이내 조건을 충족하지 못하므로 승인 불가. 다만 1년 이내이므로 무상 AS 가능하므로 우선 AS를 제안하는 것이 정책상 적절하며, 필요 시 불만족 보상으로 2,000원 적립도 고려 가능.
# 결정 : 거절
# 행동 가이드 : 상담원이 해야 할 행동 가이드: 1) 고객에게 교환/환불은 규정상 불가하다고 명확히 안내하되, 1년 이내 무상 AS가 가능하다고 설명합니다. 2) 문제 재현 여부를 확인하기 위해 모델명/시리얼 넘버, 구매 증빙 여부, Bluetooth 문제 재현 방법 등을 수집합니다. 3) AS 처리 방법 선택을 안내합니다. 매장 방문 접수 또는 택배 무상 회수 중 선택하고 필요한 경우 배송 라벨을 제공합니다. 4) AS의 예상 소요 기간과 처리 결과(수리 여부, 부품 교체 여부, 교체 여부) 및 후속 조치를 설명합니다. 5) 박스 여부는 AS에 영향을 주지 않는다고 안내하되, 필요 시 박스 여부를 확인합니다. 6) 고객이 원하면 불만족 보상으로 2,000원 적립 가능 여부를 검토하고 가능하면 진행합니다. 7) 모든 진행 사항을 내부 티켓에 기록하고, 고객에게 확정된 일정과 절차를 문자/이메일로 재확인합니다.
# ----------------------------------------------------------------------------------------------------

# %%
# Prompt Chaining 기법   이전 단계의 reasoning을 이용
# 앞의 판단 결과에 따라서 (승인/거절) 톤앤매너를 다르게 해서 이메일을 작성

# 승인 : 친절하고 빠르게 안내
# 거절 : 단호하게 거절하되 공감하는 톤

def draft_email(final_data):
    # 정보추출
    product = final_data['product']
    customer_issue = final_data['content']
    decison = final_data['decision_info']['decision']
    reason = final_data['decision_info']['reasoning']
    tone = '매우 정중하고 사과하는 태도' if decision == '승인' else '안타까워하며 공감하지만 원칙을 지키는 태도'

    prompt = f'''
        고객에게 보낼 이메일 작성 해줘

        상황 : 고객이 {product}에 대해 {customer_issue} 라고 문의
        결정 : {decison}
        이유 : {reason}
        작성 톤 : {tone}

        이메일 형식:
        제목 : 문의하신 {product}건에 대한 답변입니다.
        내용 : (인사 - 공감 - 결정 내용 통보 - 이유 설명 - 마무리)
    '''
    response = client.chat.completions.create(
        model = 'gpt-5-nano',
        messages=[{'role':'user', 'content':prompt}]
    )
    return response.choices[0].message.content
for res in decision_results:
    email = draft_email(res)
    print(email)
    print('-'*100)
# Out:
# 제목: 문의하신 무선 청소기건에 대한 답변입니다.
#
# 안녕하세요, 고객님.
#
# 먼저, 현재 상황으로 인해 불편을 겪으신 점 진심으로 안타깝게 생각합니다. 무선 청소기의 소음과 충전 이슈로 불편을 드려 대단히 죄송합니다.
#
# 고객님의 환불 요청에 대해 내부 정책에 따라 아래와 같이 안내드립니다.
#
# 결정 내용
# - 환불은 규정상 처리해 드리기 어렵고, 대신 무상 AS를 통해 문제를 해결하는 것을 권장드립니다.
#
# 이유 설명
# 1) 단순 변심 환불(조항 1)은 박스가 온전해야 한다는 조건이 있습니다. 그러나 현재 박스가 없으므로 해당 조건에 부합하지 않습니다.
# 2) 제품 불량으로 인한 환불(조항 2)은 30일 이내에 가능하나, 구입 후 기간이 경과했습니다.
# 3) 불만족 보상(조항 3)은 환불은 불가하더라도 소정의 적립금 지급 여부를 검토할 수 있습니다. 다만 구체적 지급 조건은 운영 가이드에 따릅니다.
# 4) AS 규정(조항 4)은 구매 후 1년 이내 무상 AS가 가능하므로, 현 상황에서 가장 타당한 해결 경로는 AS를 통해 문제를 해결하는 것입니다.
#
# AS 진행 안내
# - AS 신청 시 필요 정보: 구매처/구매일, 주문번호(가능하면), 모델명 및 시리얼 번호, 문제 현상(소음 및 충전 이슈)의 상세 설명, 가능하면 문제 재현 영상이나 사진
# - 접수 방법: 고객센터 또는 온라인 접수 채널을 통해 접수하실 수 있습니다. 접수 후 담당 팀이 수리 가능 여부와 일정 등을 안내해 드립니다.
# - 처리 내용: 무상 AS 대상 부품 교체 또는 수리 등 상황에 맞는 조치를 진행합니다.
#
# 고객님의 편의를 위해 최대한 신속하고 원활하게 도와드리겠습니다. 추가로 필요하신 정보가 있거나 AS 접수를 원하시면 언제든지 연락 주시기 바랍니다.
#
# 감사합니다.
#
# [회사명] 고객지원팀
# ----------------------------------------------------------------------------------------------------
# 제목: 문의하신 여름용 셔츠건에 대한 답변입니다.
#
# 안녕하세요, 다판다 고객센터입니다.
#
# 먼저 보내주신 문의에 대해 자세히 확인했고, 여름용 셔츠의 사이즈 차이로 인한 불편과 배송 지연으로 많이 불편하셨을 고객님의 상황에 진심으로 공감합니다. 불편을 드려 정말 죄송합니다.
#
# 결정 내용
# 고객님의 교환 요청은 현재 다판다의 정책상 승인하기 어렵습니다.
#
# 이유
# - 다판다의 교환/환불 규정에는 명시적으로 ‘교환’ 조항이 없습니다.
# - 구매일 2025-02-10에서 오늘 2025-11-24까지의 경과일은 약 287일로, 7일 이내 단순 변심 환불이나 30일 이내 제품 불량 환불 요건에 해당하지 않습니다.
# - AS 규정은 구매 후 1년 이내 무상으로 제공되나, 사이즈 차이에 따른 교환은 규정상 다루지 않습니다.
#
# 대안
# - 불만족 보상으로 2,000원 적립금을 지급해 드릴 수 있습니다.
# - 제조상의 결함 여부에 따라 AS 여부를 추가로 검토해 드릴 수 있습니다. 원하시면 해당 건에 대해 재검토를 진행하겠습니다.
#
# 다음에 도움이 필요하신 경우
# - 2,000원 적립금 적용 방법이나 AS 절차에 대한 구체적 안내를 원하시면 회신해 주세요.
# - 추가로 확인하고 싶은 사항이나 다른 요청이 있으면 말씀해 주시면 최대한 도와드리겠습니다.
#
# 다시 한번 불편을 드려 죄송합니다. 이해해 주셔서 감사합니다.
#
# 다판다 고객센터 드림
# ----------------------------------------------------------------------------------------------------
# 제목 : 문의하신 블루투스 키보드건에 대한 답변입니다.
#
# 내용
# 고객님 안녕하세요. 블루투스 키보드의 연결 문제로 불편을 겪으신 점 정말 안타깝게 생각합니다.
#
# 요청하신 교환/환불은 당사 정책상 승인하기 어렵습니다. 다만 상황을 정확히 안내드리면, 구매일은 2025-03-10이고 오늘은 2025-11-24로 약 8개월 반이 경과하여 1년 이내의 기간에 해당합니다. 그러나 교환/환불은 7일 이내 또는 30일 이내의 조건 충족이 필요하므로 현재 시점으로는 승인할 수 없습니다. 이와 같은 이유로 교환/환불 대신 무상 AS를 우선 제안드립니다. 또한 필요하신 경우 불만족 보상으로 2,000원 적립도 검토해 드릴 수 있습니다.
#
# 마무리로, AS를 통해 문제를 해결하는 방향이 원칙에 맞고 가장 빠른 해결책이 될 수 있습니다. AS 접수 방법 및 절차는 아래와 같습니다.
# - AS 접수 방법: 당사 고객센터 또는 홈페이지의 AS 접수 폼을 이용해 주세요. 구매 증빙(영수증)과 모델명/시리얼, 문제 증상, 박스 보유 여부를 함께 기재해 주시면 신속히 처리됩니다.
# - 처리 예정 안내: 접수 확인 후 진단 및 수리(또는 부품 교체) 절차가 진행되며, 상황에 따라 소요 기간이 달라질 수 있습니다. 가능하면 최대한 신속히 해결되도록 노력하겠습니다.
# - 추가 옵션: 불만족 보상으로 2,000원 적립을 원하신다면 접수 시 함께 요청해 주시면 확인 후 반영 여부를 안내드리겠습니다.
#
# 다시 한번 불편을 드려 죄송합니다. 원하시면 바로 AS 절차를 시작해 드리겠습니다. 궁금하신 점이나 추가로 필요한 사항이 있으시면 언제든지 문의해 주세요. 감사합니다.
# ----------------------------------------------------------------------------------------------------
